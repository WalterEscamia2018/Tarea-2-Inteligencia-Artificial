# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("unemployment analysis.csv", delimiter=",")

# %%
df
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
df.dtypes
# Out:
# Country Name     object
# Country Code     object
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
df.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.438979  ...    8.062553
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
dffinal = pd.DataFrame()
for y in df.columns[ 2 :  ]:
    dftemp  = df.loc[ :  , ['Country Name','Country Code', y] ]
    dftemp['Year'] = y
    dftemp.columns = ['Country Name', 'Country Code', 'Value', 'Year']
    dftemp = dftemp.loc[ : , ['Country Name', 'Country Code', 'Year', 'Value'] ]
    
    dffinal = pd.concat([dffinal, dftemp])

# %%
dffinal
# Out:
#                     Country Name Country Code  Year  Value
# 0    Africa Eastern and Southern          AFE  1991   7.80
# 1                    Afghanistan          AFG  1991  10.65
# 2     Africa Western and Central          AFW  1991   4.42
# 3                         Angola          AGO  1991   4.21
# 4                        Albania          ALB  1991  10.31
# ..                           ...          ...   ...    ...
# 230                        Samoa          WSM  2021   9.84
# 231                  Yemen, Rep.          YEM  2021  13.57
# 232                 South Africa          ZAF  2021  33.56
# 233                       Zambia          ZMB  2021  13.03
# 234                     Zimbabwe          ZWE  2021   5.17
#
# [7285 rows x 4 columns]

# %%
# Out:
# Index(['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df1 = pd.read_csv("world_population.csv", delimiter=",")

# %%
df1
# Out:
#     Rank Country Code                 Country Name           Capital  \
# 0     36          AFG                  Afghanistan             Kabul
# 1    138          ALB                      Albania            Tirana
# 2     34          DZA                      Algeria           Algiers
# 3    213          ASM               American Samoa         Pago Pago
# 4    203          AND                      Andorra  Andorra la Vella
# ..   ...          ...                          ...               ...
# 230  172          ESH               Western Sahara          El Aaiún
# 231   46          YEM                        Yemen             Sanaa
# 232   63          ZMB                       Zambia            Lusaka
# 233   74          ZWE                     Zimbabwe            Harare
# 234    0          AFE  Africa Eastern and Southern                 A
#
#     Continent  2022 Population  2020 Population  2015 Population  \
# 0        Asia       41128771.0       38972230.0       33753499.0
# ...

# %%
df1.columns
# Out:
# Index(['Rank', 'Country Code', 'Country Name', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
resultado1 = df.merge(df1, how='left', on='Country Code')
resultado1
# Out:
#                   Country Name_x Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...  2015 Population  2010 Population  \
# ...

# %%
resultado2 = dffinal.merge(resultado1, how='left', on='Country Code')
resultado2.loc[ : ,['Country Code', 'Country Name', 'Capital', 'Continent', 'Area (km²)','2020','2021']]
# Out:
#      Country Code                 Country Name   Capital Continent  \
# 0             AFE  Africa Eastern and Southern         A    Africa
# 1             AFG                  Afghanistan     Kabul      Asia
# 2             AFW   Africa Western and Central       NaN       NaN
# 3             AGO                       Angola    Luanda    Africa
# 4             ALB                      Albania    Tirana    Europe
# ...           ...                          ...       ...       ...
# 7280          WSM                        Samoa      Apia   Oceania
# 7281          YEM                  Yemen, Rep.     Sanaa      Asia
# 7282          ZAF                 South Africa  Pretoria    Africa
# 7283          ZMB                       Zambia    Lusaka    Africa
# 7284          ZWE                     Zimbabwe    Harare    Africa
#
#       Area (km²)   2020   2021
# 0            0.0   7.56   8.11
# 1       652230.0  11.71  13.28
# 2            NaN   6.77   6.84
# 3      1246700.0   8.33   8.53
# ...
